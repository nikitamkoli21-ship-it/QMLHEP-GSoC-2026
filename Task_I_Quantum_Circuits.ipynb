# %% [markdown]
# <a href="https://colab.research.google.com/github/nikitamkoli21-ship-it/QMLHEP-GSoC-2026/blob/main/Task_I_Quantum_Circuits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pennylane matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 39.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 54.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 86.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 73.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 104.5 MB/s eta 0:00:00
# ...

# %%
import pennylane as qml
import numpy as np

dev = qml.device("default.qubit", wires=5)

@qml.qnode(dev)
def circuit():
    for i in range(5):
        qml.Hadamard(wires=i)

    qml.CNOT(wires=[0, 1])
    qml.CNOT(wires=[1, 2])
    qml.CNOT(wires=[2, 3])
    qml.CNOT(wires=[3, 4])

    qml.SWAP(wires=[0, 4])

    qml.RX(np.pi / 2, wires=0)

    return qml.state()

circuit()
print(qml.draw(circuit)())
# Out:
# 0: ──H─╭●──────────╭SWAP──RX(1.57)─┤  State
# 1: ──H─╰X─╭●───────│───────────────┤  State
# 2: ──H────╰X─╭●────│───────────────┤  State
# 3: ──H───────╰X─╭●─│───────────────┤  State
# 4: ──H──────────╰X─╰SWAP───────────┤  State

# %%
dev2 = qml.device("default.qubit", wires=5)

@qml.qnode(dev2)
def swap_test_circuit():
    qml.Hadamard(wires=0)
    qml.RX(np.pi / 3, wires=1)
    qml.Hadamard(wires=2)
    qml.Hadamard(wires=3)
    qml.Hadamard(wires=4)
    qml.CSWAP(wires=[4, 0, 2])
    qml.CSWAP(wires=[4, 1, 3])
    qml.Hadamard(wires=4)
    return qml.expval(qml.PauliZ(wires=4))

swap_test_circuit()
print(qml.draw(swap_test_circuit)())
# Out:
# 0: ──H────────╭SWAP──────────┤
# 1: ──RX(1.05)─│─────╭SWAP────┤
# 2: ──H────────├SWAP─│────────┤
# 3: ──H────────│─────├SWAP────┤
# 4: ──H────────╰●────╰●─────H─┤  <Z>
